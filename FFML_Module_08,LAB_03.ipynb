# %% [markdown]
# <a href="https://colab.research.google.com/github/Gimmi-07/FFML_Projects_and_Labs/blob/main/FFML_Module_08%2CLAB_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT
#
# FMML Module 08, Lab 03 <br>
#  NAME: Grishma Yenchilwar ( grishma.yenchilwar.cse@ghrce.raisoni.net ) <br>
#  Date: 25 Mar 2024 <br>

# %% [markdown]
#  Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 09:50:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   164MB/s    in 0.4s
#
# 2024-03-31 09:50:07 (164 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3167   1505.06814v1  We apply belief propagation to a Bayesian bipa...    cs
# 30977  1802.00121v1  This paper presents a method to learn a decisi...    cs
# 22591  1702.03522v2  Spectral clustering is amongst the most popula...  stat
# 17512  1711.08792v1  Prediction without justification has limited u...    cs
# 10851  1502.04689v2  In this paper we focus on the problem of compl...    cs
# ...             ...                                                ...   ...
# 36974  1601.04943v3  We study the semantic foundation of expressive...    cs
# 37680  1801.00218v1  Game-theoretic centrality is a flexible and so...    cs
# 40463   1110.2897v3  We study the topic of dimensionality reduction...    cs
# 36024   0910.2874v1  The major function of this model is to access ...    cs
# 23427   1204.1678v1  In this paper, we propose an automatic analysi...    cs
#
#                                                    title  year  \
# 3167   Discrete Independent Component Analysis (DICA)...  2015
# 30977               Interpreting CNNs via Decision Trees  2018
# 22591  Spectral Clustering via Graph Filtering: Consi...  2017
# 17512      SPINE: SParse Interpretable Neural Embeddings  2017
# 10851                Exact tensor completion using t-SVD  2015
# ...                                                  ...   ...
# 36974  Semantics for probabilistic programming: highe...  2016
# 37680        Game-theoretic Network Centrality: A Review  2017
# 40463  Randomized Dimensionality Reduction for k-mean...  2011
# 36024                An Agent Based Classification Model  2009
# 23427  A New Approach for Arabic Handwritten Postal A...  2012
#
#                                                 keywords
# 3167   [propagation, bipartite, independent, variable...
# 30977  [quantitatively, prediction, convolutional, fo...
# 22591  [clustering, community, detection, clustering,...
# 17512  [prediction, justification, attributed, expres...
# 10851  [completion, multidimensional, decomposition, ...
# ...                                                  ...
# 36974  [foundation, expressive, probabilistic, progra...
# 37680  [theoretic, centrality, sophisticated, importa...
# 40463  [dimensionality, reduction, clustering, dimens...
# 36024  [wisconsin, categories, anomalous, detection, ...
# 23427  [automatic, handwriting, addresses, recognitio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3167     [propagation, bipartite, independent, variable...
# 30977    [quantitatively, prediction, convolutional, fo...
# 22591    [clustering, community, detection, clustering,...
# 17512    [prediction, justification, attributed, expres...
# 10851    [completion, multidimensional, decomposition, ...
#                                ...
# 31140    [satellite, technology, resolution, techniques...
# 10602    [algorithm, algorithm, supervised, unsupervise...
# 6064     [inexpensive, neuropsychological, screening, c...
# 11873    [convolutional, enhancement, enhancement, deno...
# 26277    [interpersonal, association, friendliness, dom...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8916 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="69218adf-3126-42a0-995c-4319a9a802b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69218adf-3126-42a0-995c-4319a9a802b7")) {                    Plotly.newPlot(                        "69218adf-3126-42a0-995c-4319a9a802b7",                        [{"x":["counterpart","inference","bipartite","implemented","character","simulations","independent","component","generative","variables","factorial","contributes","manipulated","propagation","following","contribute","representations","memorized","interpreting","convolutional","represent","experiments","potential","organizes","explanation","prediction","quantitatively","quantitative","demonstrated","connected","describing","effectiveness","interpretability","dimensional","clustering","laplacian","computing","consistency","detection","algorithm","eigenvectors","prohibitively","performed","filtering","embedding","dimensionality","decomposition","implement","approximate","stochastic","approximation","consistently","conditions","algorithms","community","denoising","embeddings","underlying","distributed","beginning","outperform","benchmark","attributed","generates","complexity","downstream","expressive","efficient","interpretable","resulting","justification","autoencoders","evaluation","algebraic","proportion","completion","multidimensional","performance","approaches","optimization","properties","relaxation","optimality","overwhelming","sequences","probability","minimizes","flattening","guarantee","completing","factorization","gracefully","applicable","likelihood","guaranteed","conservative","theoretical","successfully","boundaries","trajectories","classical","approximately","reduction","electrical","acquisition","addressed","efficiency","renewable","information","additional","improving","transmission","computational","forecasting","especially","objective","resources","traditional","distribution","generation","consumers","improvements","illustrate","significant","necessity","elegantly","expectation","derivations","maximisation","autonomous","supervised","unsupervised","posterior","decisions","behaviours","parameters","including","automated","operators","literature","tremendously","framework","surveillance","comparison","described","introduced","procedure","variational","activities","invaluable","presented","transportation","localisation","behaviour","divergences","analysing","projection","involving","distances","enforcing","pervasive","manifolds","transformed","admissible","potentially","reductions","establish","estimation","projections","convenience","aforementioned","distortions","divergence","applications","normalisation","adversarial","observations","synthetic","simulator","wasserstein","increasingly","effectively","incorporating","difficult","introduce","continuous","objectives","replacing","minimizing","tractable","differentiable","producing","empirical","minimized","experimental","simulators","generalize","generalized","combinatorial","solutions"],"y":[18,210,5,99,44,42,130,105,132,124,4,16,4,62,86,30,253,3,9,381,121,570,143,4,20,226,24,77,104,63,45,214,21,170,153,16,145,62,348,789,9,8,136,58,97,57,70,77,98,126,130,38,134,601,76,40,85,97,109,6,111,228,12,61,211,10,30,417,38,158,15,23,267,15,9,30,23,861,436,331,193,21,24,5,96,178,22,1,32,5,37,3,41,75,35,6,159,100,38,20,98,27,102,5,40,39,173,2,682,101,92,12,287,16,128,158,76,150,227,150,1,105,73,234,13,2,38,3,0,53,213,140,35,60,8,229,262,99,49,125,3,564,28,158,71,125,98,62,38,3,175,10,8,30,6,11,54,48,34,9,11,12,25,9,37,10,45,203,29,6,18,4,25,460,4,112,54,148,10,8,46,123,50,129,315,111,34,14,50,23,28,22,149,10,395,3,48,82,47,148],"type":"bar"},{"x":["counterpart","inference","bipartite","implemented","character","simulations"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.5957446808510638);'>Generation</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.4888888888888889);'>Evolution</span> <span style=''>Control</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surrogate</span> <span style=''>Models</span> <br/><br/><span style=''>The</span> <span style=''>interest</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerating</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizers</span> <span style=''>has</span> <span style=''>resulted</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>model</span> <span style=''>assisted</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6097560975609756);'>Covariance</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.32110091743119257);'>Adaptation</span> <span style='background-color:rgba(0, 255, 0, 0.4888888888888889);'>Evolution</span> <span style=''>Strategy</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizer</span> <span style=''>The</span> <span style=''>version</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surrogate</span> <span style=''>CMA</span> <span style=''>ES</span> <span style=''>uses</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>or</span> <span style=''>random</span> <span style=''>forests</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>models</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5957446808510638);'>generation</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.4888888888888889);'>evolution</span> <span style=''>control</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3191489361702127);'>improvement</span> <span style=''>for</span> <span style=''>S</span> <span style=''>CMA</span> <span style=''>ES</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>with</span> <span style=''>the</span> <span style=''>sACM</span> <span style=''>ES</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>generations</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style=''>model</span> <span style=''>before</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>retraining</span> <span style=''>is</span> <span style=''>adjusted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Semisupervised</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style=''>Models</span> <br/><br/><span style=''>Neural</span> <span style=''>network</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>are</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>However</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>a)</span> <span style=''>cannot</span> <span style=''>account</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>and</span> <span style=''>b)</span> <span style=''>lack</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>the</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>process</span> <span style=''>To</span> <span style=''>avoid</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>we</span> <span style=''>first</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>inputs</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginalize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>inputs</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>missing</span> <span style=''>labels</span> <span style=''>in</span> <span style=''>this</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Following</span> <span style=''>this</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>to</span> <span style=''>be</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feeling</span> <span style=''>the</span> <span style=''>Bern</span> <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.6494845360824743);'>Estimators</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.40000000000000013);'>Bernoulli</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilities</span> <span style=''>of</span> <span style=''>Pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparisons</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3103448275862068);'>aggregating</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>data</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>outcome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>for</span> <span style=''>future</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>among</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.32142857142857134);'>collection</span> <span style=''>of</span> <span style=''>n</span> <span style=''>items</span> <span style=''>Working</span> <span style=''>within</span> <span style=''>a</span> <span style=''>flexible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>imposes</span> <span style=''>only</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.37157107231920206);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>transitivity</span> <span style=''>(SST)</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>adaptivity</span> <span style=''>index</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>the</span> <span style=''>indifference</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>the</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.30158730158730157);'>measuring</span> <span style=''>the</span> <span style=''>usual</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.6387096774193548);'>estimator</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>adaptivity</span> <span style=''>index</span> <span style=''>also</span> <span style=''>captures</span> <span style=''>the</span> <span style=''>extent</span> <span style=''>to</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6387096774193548);'>estimator</span> <span style=''>adapts</span> <span style=''>to</span> <span style=''>instance</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>an</span> <span style=''>oracle</span> <span style='background-color:rgba(255, 0, 0, 0.6387096774193548);'>estimator</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>three</span> <span style=''>main</span> <span style=''>results</span> <span style=''>that</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Task</span> <span style=''>Driven</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <br/><br/><span style=''>Modeling</span> <span style=''>data</span> <span style=''>with</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>a</span> <span style=''>few</span> <span style=''>elements</span> <span style=''>from</span> <span style=''>a</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>has</span> <span style=''>been</span> <span style=''>the</span> <span style=''>focus</span> <span style=''>of</span> <span style=''>much</span> <span style=''>recent</span> <span style=''>research</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neuroscience</span> <span style=''>and</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>For</span> <span style=''>signals</span> <span style=''>such</span> <span style=''>as</span> <span style=''>natural</span> <span style=''>images</span> <span style=''>that</span> <span style=''>admit</span> <span style=''>such</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>it</span> <span style=''>is</span> <span style=''>now</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>that</span> <span style=''>these</span> <span style=''>models</span> <span style=''>are</span> <span style=''>well</span> <span style=''>suited</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restoration</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>context</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>amounts</span> <span style=''>to</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>done</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>tools</span> <span style=''>The</span> <span style=''>same</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>also</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>features</span> <span style=''>from</span> <span style=''>data</span> <span style=''>for</span> <span style=''>other</span> <span style=''>purposes</span> <span style=''>eg</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>but</span> <span style=''>tuning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>way</span> <span style=''>for</span> <span style=''>these</span> <span style=''>tasks</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>to</span> <span style=''>be</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>In</span> <span style=''>this</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10297811266594904)
# 	information (0.2447075708647291)
# 	processing (0.11051309651955507)
# 	representation (0.14459992823824902)
# 	segmentation (0.07822030857552924)
# 	experimental (0.14172945819878005)
# 	detection (0.12486544671689989)
# 	different (0.2687477574452817)
# 	recognition (0.1320416218155723)
# 	convolutional (0.13670613562970937)
#
# Some Statistics words are:
# 	statistical (0.14555389965226032)
# 	theoretical (0.14456035767511177)
# 	stochastic (0.1366120218579235)
# 	algorithm (0.3770491803278688)
# 	variables (0.13859910581222057)
# 	estimation (0.17088922006954793)
# 	distribution (0.18827620466964728)
# 	dimensional (0.17834078489816194)
# 	regression (0.17237953303527073)
# 	inference (0.20615996025832092)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ba154d1e-7691-4923-b162-45f2e66977c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba154d1e-7691-4923-b162-45f2e66977c6")) {                    Plotly.newPlot(                        "ba154d1e-7691-4923-b162-45f2e66977c6",                        [{"x":["counterpart","inference","bipartite","implemented","character","simulations","independent","component","generative","variables","factorial","contributes","manipulated","propagation","following","contribute","representations","memorized","interpreting","convolutional","represent","experiments","potential","organizes","explanation","prediction","quantitatively","quantitative","demonstrated","connected","describing","effectiveness","interpretability","dimensional","clustering","laplacian","computing","consistency","detection","algorithm","eigenvectors","prohibitively","performed","filtering","embedding","dimensionality","decomposition","implement","approximate","stochastic","approximation","consistently","conditions","algorithms","community","denoising","embeddings","underlying","distributed","beginning","outperform","benchmark","attributed","generates","complexity","downstream","expressive","efficient","interpretable","resulting","justification","autoencoders","evaluation","algebraic","proportion","completion","multidimensional","performance","approaches","optimization","properties","relaxation","optimality","overwhelming","sequences","probability","minimizes","flattening","guarantee","completing","factorization","gracefully","applicable","likelihood","guaranteed","conservative","theoretical","successfully","boundaries","trajectories","classical","approximately","reduction","electrical","acquisition","addressed","efficiency","renewable","information","additional","improving","transmission","computational","forecasting","especially","objective","resources","traditional","distribution","generation","consumers","improvements","illustrate","significant","necessity","elegantly","expectation","derivations","maximisation","autonomous","supervised","unsupervised","posterior","decisions","behaviours","parameters","including","automated","operators","literature","tremendously","framework","surveillance","comparison","described","introduced","procedure","variational","activities","invaluable","presented","transportation","localisation","behaviour","divergences","analysing","projection","involving","distances","enforcing","pervasive","manifolds","transformed","admissible","potentially","reductions","establish","estimation","projections","convenience","aforementioned","distortions","divergence","applications","normalisation","adversarial","observations","synthetic","simulator","wasserstein","increasingly","effectively","incorporating","difficult","introduce","continuous","objectives","replacing","minimizing","tractable","differentiable","producing","empirical","minimized","experimental","simulators","generalize","generalized","combinatorial","solutions","techniques","typically","supported","developing","carefully","constraints","interpret","reasoning","constraint","methodology","semantics","traditionally","relations","isomorphism","constructive","specialised","expressed","programming","development","parameter","generated","estimating","asymptotically","interpretation","impossible","dependent","distributions","consistent","considered","stationary","evaluations","estimates","collaborative","representation","pointwise","constructing","accommodate","demonstrating","analyzing","permutation","outperforms","permutations","recommendation","extending","respectively","statistical","favorable","asymptotic","controller","highlight","hyperparameter","estimations","regulator","computationally"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	maximisation
# 	smoothers
# 	interpolates
# 	covariances
# 	discretised
# 	sustainability
# 	governing
# 	personalization
# 	sparsities
# 	changepoint
# 	dendrogram
# 	ellipsoid
# 	nonconvexity
# 	methylation
# 	discharge
# 	childrens
# 	physiologic
# 	sparsified
# 	overtraining
# 	integrality
# Some words which never appear in Statistics papers:
# 	memorized
# 	organizes
# 	pervasive
# 	distortions
# 	specialised
# 	regulator
# 	locomotion
# 	acknowledged
# 	preposition
# 	attachment
# 	watermark
# 	ownership
# 	watermarking
# 	disappear
# 	hypercolumns
# 	interpreter
# 	intrusions
# 	thesaurus
# 	pedestrian
# 	annotating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0839449824215136e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
